# %%
"""
Created on Thu Jan 24 18:28 2023
@author: Ikram.Lazaar
"""
"""
    DocString:
    
    A) Introduction:
    Heavy Rain is an interactive action adventure murder mystery from David 
    Cage and Quantic Dream. 
    The game revolves around a serial killer called the Origami 
    Killer. They are known for murdering their victims by drowning them in 
    rainwater and leaving a piece of Origami 
    at the scene. It has a few different ways that it can end depending, 
    on the choices of the player, 17 to be precise.
     
    You play as a few different protagonists committed to figuring out the 
    identity of the killer and putting an end to their crimes. Their level of 
    success depends on you. Your choices impact how each protagonist's
    story plays out.
    
    B) Known Bugs and/or Errors:
    None.
    
"""

import sys
from sys import exit
import random
import time

# Let's start by defining a function that will allow user to start the game:
def start():
  
    print('\t\t\t START OF THE GAME \n' + '=' *80 +"""

Ethan Mars is a successful architect living a happy life with his wife Grace 
and two sons Jason and Shaun.

One day, Jason gets killed in a car accident and the family dinamic falls apart.

One day, Norman jayden, and FBI profiler, was sent to assist in the origami 
serial killer invistigation.

Meanwhile, a retired police lieutenant named Scott Shelby is working as a 
private invistigator for the families of the victims of the origami serial 
killer. \n
""" + '-_' *40)

    input("<Press enter to continue>\n")
    
    print("Good luck!")
    
    level_1()

    
# to link the first funtion with the folling one, we call the level_1 function
# in the returned results of the first function.


#In the following funtion, we will start giving user choices to frame the game.

def level_1():
    print("""
    \t\t\t Level 1:

    One day, Shaun gets kidnapped and Ethan recieves a box from the 
    Origami serial killer. Inside the box 4 figurines:
    a bear, a butterfly, a lizard, and a rat, as well as a gun, 
    a cellphone, and a micro-chip.""")
    
# in the following step, we want to controll the string input of the user
# we want to make sure the game stops if he exists or move forward otherwise
    while True:
        insert_chip = \
        input(prompt = f"do you want to insert the chip in the cell?")
        if insert_chip.lower() in "no" or insert_chip.lower() in "n" \
        or insert_chip.lower() in "i don't want to":
            user_input = input(prompt = "do you want to exit?" "y/n").lower()
            if user_input.lower() in "yes" or user_input.lower() in "y" \
            or user_input.lower() in 'exit':
                print('okay. Goodbye!')
                break    
            else:
                print("""sorry. I don't quiet understand what you mean. 
                Can you try again please?""")
                insert_chip = \
                input(prompt = f"do you want to insert the chip in the cell?")
        elif insert_chip.lower() in "yes" or insert_chip.lower() in "y" \
        or insert_chip.lower() in "i want to":

            print("""
Ethan inserts the chip in the cell and sees Shaun in a well crying for help.
                    
""" +'*'*80)
            level_2()
            
        else:
            print("""sorry. I don't quiet understand what you mean. 
            Can you try again please?""")
            insert_chip = \
            input(prompt = f"do you want to insert the chip in the cell?")
            if insert_chip.lower() in "no" or insert_chip.lower() in "n" \
            or insert_chip.lower() in "i don't want to":
                user_input = input(prompt = "do you want to exit?" "y/n").lower()
            elif user_input.lower() in "yes" or user_input.lower() in "y" \
            or user_input.lower() in 'exit':
                print('okay. Goodbye!')
            else:
                print("""you ran out of trials. 
                Please restart the game all over again.""")
                exit(0)      
  

# In this next part, we want to give the user choice to either create an end
# of their choice, or start solving the hangman riddle:

def level_2():
    print(""" \t\t\t Level 2:

Congratulations! you moved into the second level of this game. 
\n""" + '=_'* 40+


""" \n

Ethan is now given on his phone a random set of letters to complete 
the hangman which will direct him to the next location:

                                -5---------
                                R---E---T----
""")
    
    input("<Click on any key to continue.>\n")

    print(
"""
The next day, Ethan  meets Madison Paige, a journalist who came to write about 
his child's story.

Ethan goes to the adress on the butterfly figurine the same day and finds an 
entrance to a tunnel. He crawls his to the electrical capacitors. 
""")

    print("""Press 1 to make Ethan go through the electrical capacitors and 
    reach the opposite side of the room.""")
    print("Press 2 if you think that Ethan should drop the mission.")
    print("press 3 to exit")
    
# let's use a while loop to give user 3 choices and control his input:

    while True:
        choice = input(prompt = f"What should Ethan do?")
        if choice == '1':
            print("""


            Wise choice!

            Ethan makes it to the other side of the room and finds a chip 
            with several more letters to complete the hangman:
                                 -52--------
                                 R---E-ELT----
                      """)
            level_3()
        elif choice == '2':
            print("""
                                GAME OVER!!
            --> You have chosen the worst senario that this game comes with: 
            - Shaun dies and the serial killer remains free.
            - Shaun's Father (Ethan) commits suicide. 
            - Madison is murdered while strapped to a torture table. 
            - The Origami case is closed""")
            exit(0)
        elif choice == '3':
            print('okay. Goodbye!')
            exit(0)
        else:
            print("""sorry. I don't quiet understand what you mean. 
            Choose a number from 1 to 3.""")
            choice = \
            input(prompt = f"What should Ethan do? choose from 1 to 3.")
            break
        
def level_3():
    
    input("<Click on any key to continue.>\n")
    
    print(""" \t\t\t Level 3:

Congratulations! you moved into the third level of this game. 
\n""" + '**'* 40+

""" \n

The day after, Ethan goes to the adress on the lizard, which takes him to 
an apartment. In the apartment, he finds instructions to cut a 
part of his finger to continue to the next step.

You have 15 seconds to decide the fate of Ethan's son, Shaun.

You have to be quick!!! 
""")

# this part is very useful to put a timer on users input
# this way, the game is more challenging.

    def timer_input(prompt):
        print(prompt, end="", flush=True)
        start_time = time.time() # this function is going to set a timer
        try:                     # time() funtion accepts no arguments inside!
            user_input = int(input())
        except KeyboardInterrupt:    # this is an expression to control errors
            user_input = ""
        end_time = time.time()
        elapsed_time = end_time - start_time # this part is to 
        if elapsed_time < 15:                 # calculate the duration
            return user_input
        elif elapsed_time >= 15:
            print("""Time is up! Shaun is dead :(
            Ethan falls into severe depressionand spends the rest of his life 
            in a mental hospital...""")
            exit(0) # this funtion is executed whenever a user loses the game
                    # or choses to exit
    while True:
        user_input = timer_input("choose a random number from 1 to 15: ")
        print("You entered:", user_input)

# let's print the senarios!!!

        if user_input in range(0,6):
            print("""you chose to cut your finger with a butter knife!. Ouch! 
            that must hurt. but you are moving forward!""")
            print(

"""
Great! now, Ethan goes back to his home.

Madison wanting to help Ethan, she went to talk to the owner of the apartment, 
Baker, where Ethan cut his finger. She gets drugged by Baker and wakes up on 
a surgery table. Baker is a killer.


After an fight between the two, Madison manages to kill Baker and escape.

Madison discovers that there is another man that rent the apartment owned by 
Blake.
The man's name is John Sheppard
\n
"""+ '*'* 80)
            level_4()
        elif user_input in range(6,10):
            print("""You have decided to cut your finger using a sharp blade. 
            you are brave!""")
            print(

"""
Great! now, Ethan goes back to his home.

Madison wanting to help Ethan, she went to talk to the owner of the apartment, 
Baker, where Ethan cut his finger. She gets drugged by Baker and wakes up on 
a surgery table. Baker is a killer.


After an fight between the two, Madison manages to kill Baker and escape.

Madison discovers that there is another man that rent the apartment owned by 
Blake.
The man's name is John Sheppard
\n
"""+ '*'* 80)
            level_4()
        elif user_input in range(10,16):
            print("""GAME OVER! You have decided that your son is not worth 
            cutting your finger for! what a shame!!
            
            Shaun dies, Madison never gets a chance to fall in love with
            Ethan, and the Origami Serial Killer remains free.""")
            
            exit(0) 
        else:
            print("Your entry is out of scope. Try again")
            user_input = timer_input("choose a random number from 1 to 15: ")
            break
        

def level_4():
    input("<Press enter to continue>\n")
    
    print(""" \t\t\t Level 4:

Congratulations! you moved into the last stage of this game. 
\n""" + '**'* 40+

""" \n          

Ethan follows the last adress on the rat figurine, where he is given a choice 
to drink poison that will kill him in 60 minutes, which will be enough time 
to find and save his son and say goodbye.""")

    
    while True:
        user_input= input(prompt = f"Do you want to drink poison? y/n")
        
        if user_input in "no" or user_input.lower() in "n" \
        or user_input.lower() in "i don't want to":
            user_input = input(prompt = "do you want to exit?" "y/n").lower()
            if user_input.lower() in "yes" or user_input.lower() in "y" \
            or user_input.lower() in 'exit':
                print("""you lost after hard work! such a shame!
                shaun will die and the Origami killer will kill Madison""")
                exit(0)    
            else:
                print("""sorry. I don't quiet understand what you mean. 
                Can you try again please?""")
                user_input = input(prompt = f"Do you want to drink poison??")

        elif user_input.lower() in "yes" or user_input.lower() in "y" \
        or user_input.lower() in "i want to":

            print("""

You chose to drink the poison, you are now given the last hangman letters

                            852 THEODORE
                            ROOSEVELT ROAD



Meanwhile, Madison discovers that Scott is the killer by going to talk to 
his mother. 
Madison heads to scotts apartment to gather evidence.

Scott meanwhile was getting rid of all the evidence that reveals that he 
is the killer. He then traps Madison into a room once she gets there, 
and sets the whole apartment on fire.""")
            
        
        while True:
            user_input= input(prompt = f"Do you want to save Madison? y/n")
            if user_input in "no" or user_input.lower() in "n" \
            or user_input.lower() in "i don't want to":
                user_input =\
                input(prompt = "do you want to exit?" "y/n").lower()
                if user_input.lower() in "yes" or user_input.lower() in "y" \
                or user_input.lower() in 'exit':
                    print("""you lost after hard work! such a shame! 
                    you don't even get to know the ending""")
                    exit(0)
                elif user_input.lower() in "no" or user_input.lower() in "n"\
                or user_input.lower() in 'stay':
                    print("""you have reached the end of the game.
                    Madison dies, Ethan saves Shaun, 
                    but the police emprisone him
                    and the serial killer remains free.""")
                    exit(0)
                else:
                    print("""sorry. I don't quiet understand what you mean. 
                    Can you try again please?""")
                    user_input =\
                    input(prompt = f"Do you want to save Madison??")
                    break

            elif user_input.lower() in "yes" or user_input.lower() in "y" \
            or user_input.lower() in "i want to":

                print(
"""
Madison manages to escape by hiding in the fridge.

Ethan finds Shaun and is confronted by scott. While trying to find a way out, 
Scot tries to shoot ethan but is saved by Norman Jayden who got there at the 
right time. """)
                break
        
        while True:
            user_input= input(prompt = f"Do you want to kill scott? y/n")
            if user_input in "no" or user_input.lower() in "n"\
            or user_input.lower() in "i don't want to":
                user_input =\
                input(prompt = "do you want to exit?" "y/n").lower()
                if user_input.lower() in "yes" or user_input.lower() in "y"\
                or user_input.lower() in 'exit':
                    print("""you lost after hard work! such a shame! 
                    you don't even get to know the ending""")
                    exit(0)
                elif user_input.lower() in "no" or user_input.lower() in "n"\
                or user_input.lower() in 'stay':
                    print(""" Norman chases scott and gets him. Congrats!
                    Ethan saved Shaun but died after that because of the 
                    poinson.""")
                else:
                    print("""sorry. I don't quiet understand what you mean. 
                    Can you try again please?""")
                    user_input = input(prompt = f"Do you want to kill scott??")
                    break

            elif user_input.lower() in "yes" or user_input.lower() in "y" \
            or user_input.lower() in "i want to":

                print(

"""

Norman chases scott until he dies after falling into a grinder

-----------------------------------------------------------------------------

Ending:

Ethan gets Shaun out and Madison arrives to the wharehouse too.

The crime is resolved

Ethan, Madison and Shaun move into a new house, and start a new life as a 
family.

""")
                exit(0)

# Starting the game!
start()
# Out:
# 			 START OF THE GAME
# ...
#
# Ethan Mars is a successful architect living a happy life with his wife Grace
# and two sons Jason and Shaun.
#
# One day, Jason gets killed in a car accident and the family dinamic falls apart.
#
# One day, Norman jayden, and FBI profiler, was sent to assist in the origami
# serial killer invistigation.
#
# Meanwhile, a retired police lieutenant named Scott Shelby is working as a
# private invistigator for the families of the victims of the origami serial
# killer.
#
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# <Press enter to continue>
#
# Good luck!
#
#     			 Level 1:
#
#     One day, Shaun gets kidnapped and Ethan recieves a box from the
#     Origami serial killer. Inside the box 4 figurines:
#     a bear, a butterfly, a lizard, and a rat, as well as a gun,
#     a cellphone, and a micro-chip.
# do you want to insert the chip in the cell?y
#
# ...
